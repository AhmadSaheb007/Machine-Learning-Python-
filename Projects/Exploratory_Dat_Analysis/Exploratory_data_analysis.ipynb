# %% [markdown]
# # Iris Flower dataset

# %% [markdown]
# Toy Dataset: Iris Dataset: [https://en.wikipedia.org/wiki/Iris_flower_data_set]
#
# A simple dataset to learn the basics.
# 3 flowers of Iris species. [see images on wikipedia link above]
# 1936 by Ronald Fisher.
# Petal and Sepal: http://terpconnect.umd.edu/~petersd/666/html/iris_with_labels.jpg
# Objective: Classify a new flower as belonging to one of the 3 classes given the 4 features.
# Importance of domain knowledge.
# Why use petal and sepal dimensions as features?
# Why do we not use 'color' as a feature?

# %%
from sklearn.datasets import load_iris
import pandas as pd
#loading dataset . . . . . .
iris = load_iris()
# printing all datas . . . . . 
# print(iris.data)
iris_df = pd.DataFrame(iris.data, columns= ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'])
iris_df.head()

# adding spicies column . . . . . .
iris_df['spicies'] = iris.target
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    spicies
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# replacing spicies column with number 0, 1, 2
iris_df['spicies'] = iris_df['spicies'].replace(0, 'Setosa')
iris_df['spicies'] = iris_df['spicies'].replace(1, 'Verginidca')
iris_df['spicies'] = iris_df['spicies'].replace(2, 'Versicolor')
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         spicies
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

iris = pd.read_csv('iris.csv')
iris.shape
# droping 'Unnamed: 0' . . . . . 
iris = iris.drop(['Unnamed: 0'], axis=1)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Checking column names

# %%
# checking columns . . . . . .
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# chechking columns
iris['species'].value_counts()
# Out:
# species
# setosa        50
# verginica     50
# versicolor    50
# Name: count, dtype: int64

# %% [markdown]
# # 2-D scatter plot

# %%
iris.plot(kind="scatter", x="sepal_length", y="sepal_width")
plt.show()

# %% [markdown]
# # 2-D Scatter Plot using seaborn

# %%
# 2-D Scatter plot with color-coding for each flower type/class.
# Here 'sns' corresponds to seaborn. 

import seaborn as sns
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=4) \
    .map(plt.scatter, "sepal_length", "sepal_width") \
    .add_legend();
plt.show();

# Notice that the blue points can be easily seperated 
# from red and green by drawing a line. 
# But red and green data points cannot be easily seperated.
# Can we draw multiple 2-D scatter plots for each combination of features?
# How many cobinations exist? 4C2 = 6.

# %% [markdown]
# # 3-D pair plot

# %%
import plotly.express as px

df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width',
              color='species')
fig.show()

# %%
import seaborn as sns
sns.set_style("whitegrid");
sns.pairplot(iris, hue="species", height=3);
plt.show()

# %% [markdown]
# # Calculating Mean, Variance and Std-dev

# %%
iris_setosa = iris[iris['species']=='setosa']

# %%
#Mean, Variance, Std-deviation,  
print("Means:")
print(np.mean(iris_setosa["petal_length"]))
#Mean with an outlier.
print(np.mean(np.append(iris_setosa["petal_length"],50)));
print(np.mean(iris_virginica["petal_length"]))
print(np.mean(iris_versicolor["petal_length"]))

print("\nStd-dev:");
print(np.std(iris_setosa["petal_length"]))
print(np.std(iris_virginica["petal_length"]))
print(np.std(iris_versicolor["petal_length"]))
# Out:
# Means:
# 1.4620000000000002
# 2.4137254901960787
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [27], line 6
#       4 #Mean with an outlier.
#       5 print(np.mean(np.append(iris_setosa["petal_length"],50)));
# ----> 6 print(np.mean(iris_virginica["petal_length"]))
#       7 print(np.mean(iris_versicolor["petal_length"]))
#       9 print("\nStd-dev:");
#
# NameError: name 'iris_virginica' is not defined
